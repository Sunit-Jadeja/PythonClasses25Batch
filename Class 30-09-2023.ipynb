# %%
pip install matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline
# import numpy as np
# import pandas as pd
# from datetime import datetime
# import datetime as dt
# import seaborn as sns

# %%
df=pd.read_excel("/Users/sunitjadeja/Desktop/PandasData.xlsx")

# %%
df['logic_date'] = df['equipment installed on'].fillna(df['equipment shipped date']).fillna(df['equipment created on'])

# %%
df["Ageing of the product (in years)"]=(pd.to_datetime(datetime.now().date()) - df["logic_date"]).dt.days/365
df["Ageing of the product (in years)"]=df["Ageing of the product (in years)"].round(2)

# %%
df.describe()
# Out:
#        equipment number  industry segment  industry code  \
# count          54441.00          53055.00       48053.00
# mean        14753182.14             61.70      466825.68
# std          1769066.68             34.71      184534.84
# min         10046597.00              1.00      111150.00
# 25%         13419308.00             30.00      325412.00
# 50%         14783753.00             63.00      423490.00
# 75%         16343462.00             90.00      561499.00
# max         72460206.00            116.00      999990.00
#
#        most used email count ism  equipment fse number  superior equipment  \
# count                   26859.00              38402.00             3124.00
# mean                        3.25              91906.33         15516497.75
# std                         4.36                815.62          1707242.77
# min                         1.00              91102.00         10053450.00
# ...

# %%
df.describe().T
# Out:
#                                     count        mean        std         min  \
# equipment number                 54441.00 14753182.14 1769066.68 10046597.00
# industry segment                 53055.00       61.70      34.71        1.00
# industry code                    48053.00   466825.68  184534.84   111150.00
# most used email count ism        26859.00        3.25       4.36        1.00
# equipment fse number             38402.00    91906.33     815.62    91102.00
# superior equipment                3124.00 15516497.75 1707242.77 10053450.00
# active contract line value        8584.00   743345.07 1698532.02        0.00
# active contract header value      8584.00  2036133.51 4424881.72        0.00
# contract number of years          8584.00        1.64       1.12        0.49
# last contract number             15339.00 40277135.95   85330.21 40067603.00
# last contract line item          15339.00       22.32      34.45        1.00
# ...

# %%
df[np.abs(df["Ageing of the product (in years)"])>42]
# Out:
#       company code  equipment number bill-to customer number  \
# 441           2040          11974418                     NaN
# 7289          2040          16368336              0001667772
# 38515         2040          13996003              0001288317
#
#       sold-to customer number ship-to customer number   ship-to city  \
# 441                0001504296              0001504296         Raipur
# 7289               0001667772              0001667772  Visakhapatnam
# 38515              0001288317              0001288317      NEW DELHI
#
#       ship-to postal code ship-to state ship-to state name  industry segment  \
# 441                492001            CG        Chattisgarh            111.00
# 7289               531021            AP     Andhra Pradesh              8.00
# 38515              110029            DE              Delhi             47.00
#
#        ... last contract line item last contract header start date  \
# ...

# %%
df.drop([441,7289,38515], inplace=True)

# %%
df['corrected division'].unique()
# Out:
# array(['CMD', 'LSI', 'EPM', 'Unknown', 'MOL', 'CAD', 'MSD', 'MVS', 'SDG',
#        'SID', 'DIO', 'EM'], dtype=object)

# %%
x=pd.get_dummies(df['corrected division'])

# %%
x1=df.join(x)

# %%
x1[["corrected division",'CMD', 'LSI', 'EPM', 'Unknown', 'MOL', 'CAD', 'MSD', 'MVS', 'SDG',
       'SID', 'DIO', 'EM']]
# Out:
#       corrected division  CMD  LSI  EPM  Unknown  MOL  CAD  MSD  MVS  SDG  \
# 0                    CMD    1    0    0        0    0    0    0    0    0
# 3                    LSI    0    1    0        0    0    0    0    0    0
# 4                    LSI    0    1    0        0    0    0    0    0    0
# 5                    LSI    0    1    0        0    0    0    0    0    0
# 6                    LSI    0    1    0        0    0    0    0    0    0
# ...                  ...  ...  ...  ...      ...  ...  ...  ...  ...  ...
# 54558                LSI    0    1    0        0    0    0    0    0    0
# 54559                CMD    1    0    0        0    0    0    0    0    0
# 54560                LSI    0    1    0        0    0    0    0    0    0
# 54561                LSI    0    1    0        0    0    0    0    0    0
# 54562                LSI    0    1    0        0    0    0    0    0    0
#
#        SID  DIO  EM
# 0        0    0   0
# 3        0    0   0
# ...

# %%
df.sample(3,replace=True)
# Out:
#       company code  equipment number bill-to customer number  \
# 26119         2040          16899091              0001649827
# 32557         2040          16547150              0001142938
# 32450         2040          11525848              0001146926
#
#       sold-to customer number ship-to customer number      ship-to city  \
# 26119              0001649827              0001649827       Dist- Kheda
# 32557              0001142938              0001142938           KOLKATA
# 32450              0001146926              0001146926  Bathinda, Punjab
#
#       ship-to postal code ship-to state ship-to state name  industry segment  \
# 26119              387520            GU            Gujarat             63.00
# 32557              700010            WB        West Bengal             47.00
# 32450              151301            PU             Punjab             11.00
#
#        ... last contract line item last contract header start date  \
# ...

# %%
y=pd.DataFrame(np.random.randn(10).reshape(5,2),columns=["col1","col2"])

# %%
y
# Out:
#    col1  col2
# 0 -0.11  0.42
# 1 -0.62  0.59
# 2  0.98 -2.42
# 3  0.21 -0.96
# 4  1.12  0.09

# %%
mean=np.round(df["Ageing of the product (in years)"].mean(),2)

df["Ageing Average"]=np.where(df["Ageing of the product (in years)"]< mean,
                              "below average","above average")

# %%
print(mean)
# Out:
# 6.2

# %%
conditions=[(df["Ageing of the product (in years)"]<=3),
            
        (df["Ageing of the product (in years)"]>3) & 
            (df["Ageing of the product (in years)"]<=7),
            
        (df["Ageing of the product (in years)"]>7) & 
            (df["Ageing of the product (in years)"]<=14),
            
        (df["Ageing of the product (in years)"]>14) & 
            (df["Ageing of the product (in years)"]<=20),
            
        (df["Ageing of the product (in years)"]>20),
            
        df["Ageing of the product (in years)"].isnull()]


values=["new product purchased", "check for service", "service requirment", 
        "need replacement", "need replacement immidieately", "Missing"]
# Out:
#        Ageing of the product (in years) Ageing Average
# 0                                  1.84  below average
# 3                                  2.64  below average
# 4                                  2.27  below average
# 5                                  2.16  below average
# 6                                  1.42  below average
# ...                                 ...            ...
# 54558                              3.11  below average
# 54559                              3.07  below average
# 54560                              3.76  below average
# 54561                             14.35  above average
# 54562                              6.21  above average
#
# [54438 rows x 2 columns]

# %%
df['bucketing']=np.select(conditions,values)

# %%
df['bucketing'].value_counts().plot(kind='bar')
df["bucketing"].value_counts()
# Out:
# service requirment               20291
# check for service                17164
# new product purchased            15652
# need replacement                  1274
# need replacement immidieately       57
# Name: bucketing, dtype: int64

# %%
#df[['bucketing', 'Ageing Average','Ageing of the product (in years)']]
# Out:
#                    bucketing Ageing Average  Ageing of the product (in years)
# 0      new product purchased  below average                              1.84
# 3      new product purchased  below average                              2.64
# 4      new product purchased  below average                              2.27
# 5      new product purchased  below average                              2.16
# 6      new product purchased  below average                              1.42
# ...                      ...            ...                               ...
# 54558      check for service  below average                              3.11
# 54559      check for service  below average                              3.07
# 54560      check for service  below average                              3.76
# 54561       need replacement  above average                             14.35
# 54562      check for service  above average                              6.21
#
# [54438 rows x 3 columns]

# %%
x = np.array([1, 2, 3, 4])  # X-axis points
y = x*2  # Y-axis points
  
plt.plot(x, y)  # Plot the chart
plt.show()

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
student1 = [23,17,35,29,12]
plt.bar(langs,student1)
plt.show()

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
student1 = [40,17,35,29,12]
student2=[40,80,10,55,43]
plt.bar(langs, student1, color='r')
plt.bar(langs,student2, bottom=student1,color='b')
# Out:
# <BarContainer object of 5 artists>

# %%
x=np.arange(4)
labels = ['C', 'C++', 'Java', 'Python']
plt.bar(x,[10,20,30,40],color="b",width=0.25)
plt.bar(x+.25,[40,25,50,50],color="r",width=0.25)
plt.xticks(x,labels, rotation='horizontal')
plt.show()

# %%
plt.hist(np.random.rand(100), bins=10)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
Fig=plt.figure()
Fig.add_subplot(3,3,1)
Fig.add_subplot(3,3,2)
Fig.add_subplot(3,3,3)
Fig.add_subplot(3,3,4)
Fig.add_subplot(3,3,5)
Fig.add_subplot(3,3,6)
# Out:
# <Axes: >

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
z = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]



fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
ax1.hist(np.random.rand(100), bins=20)
ax2.plot(np.random.rand(100))
ax3.scatter(x, y)
ax4.pie(z, labels = mylabels)
plt.show()

# %%
fig,axis=plt.subplots(2,2)
axis[0,0].hist(np.random.rand(100),bins=10)
axis[0,1].plot(np.random.rand(100))
axis[0,1].plot(np.random.rand(100))
axis[1,0].scatter(x, y)
axis[1,1].pie(z,labels=mylabels)
plt.show()

# %%
fig,axis=plt.subplots(2,2,figsize=(10,10))
#plt.subplots_adjust(wspace=0,hspace=0)
axis[0,0].hist(np.random.rand(100),bins=10,color="r", label="histo")
axis[0,0].legend(loc="best")
axis[0,0].set_xlabel("xlabel")
axis[0,0].set_ylabel("ylabel")
axis[0,0].set_title("first plot")







axis[0,1].plot(np.random.rand(100),color="g",linestyle="--", marker="o")
plot_label={'title':'Second Plot',
           'xlabel':'X-Axis'}
axis[0,1].set(**plot_label)
axis[1,0].scatter(x, y,color="y")
axis[1,1].pie(z,labels=mylabels)
plt.show()

# %%
#sns.heatmap(df.isnull(),cbar=True)
corr=df.corr()
plt.figure(figsize=(30,20))
plt.title('Pearson Correlation of Features', y=1, size=40)
sns.heatmap(corr,linewidths=-1,vmax=1.0,square=True, cmap='hot', linecolor='Black',annot=False)
plt.show()
# Out:
# /var/folders/sy/lfmt7xdx3zj5qzj0mw834nzw0000gn/T/ipykernel_40515/1655187533.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()

# %%
corr=df.corr()
# Out:
# /var/folders/sy/lfmt7xdx3zj5qzj0mw834nzw0000gn/T/ipykernel_40515/1726683880.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()

# %%
corr
# Out:
#                                   equipment number  industry segment  \
# equipment number                              1.00             -0.07
# industry segment                             -0.07              1.00
# industry code                                -0.04              0.12
# most used email count ism                    -0.36              0.08
# equipment fse number                          0.06              0.15
# superior equipment                            0.96             -0.07
# active contract line value                   -0.10             -0.01
# active contract header value                 -0.07             -0.12
# contract number of years                      0.18             -0.25
# last contract number                          0.46              0.09
# last contract line item                       0.02             -0.01
# future contract line item                    -0.43              0.17
# Ageing of the product (in years)             -0.86              0.06
#
# ...

# %%
pd.set_option('display.float_format','{:.2f}'.format)
df.describe().T
# Out:
#                                     count        mean        std         min  \
# equipment number                 54441.00 14753182.14 1769066.68 10046597.00
# industry segment                 53055.00       61.70      34.71        1.00
# industry code                    48053.00   466825.68  184534.84   111150.00
# most used email count ism        26859.00        3.25       4.36        1.00
# equipment fse number             38402.00    91906.33     815.62    91102.00
# superior equipment                3124.00 15516497.75 1707242.77 10053450.00
# active contract line value        8584.00   743345.07 1698532.02        0.00
# active contract header value      8584.00  2036133.51 4424881.72        0.00
# contract number of years          8584.00        1.64       1.12        0.49
# last contract number             15339.00 40277135.95   85330.21 40067603.00
# last contract line item          15339.00       22.32      34.45        1.00
# ...

# %%
df[np.abs(df['Ageing of the product (in years)'])>42]
# Out:
#       company code  equipment number bill-to customer number  \
# 441           2040          11974418                     NaN
# 7289          2040          16368336              0001667772
# 38515         2040          13996003              0001288317
#
#       sold-to customer number ship-to customer number   ship-to city  \
# 441                0001504296              0001504296         Raipur
# 7289               0001667772              0001667772  Visakhapatnam
# 38515              0001288317              0001288317      NEW DELHI
#
#       ship-to postal code ship-to state ship-to state name  industry segment  \
# 441                492001            CG        Chattisgarh            111.00
# 7289               531021            AP     Andhra Pradesh              8.00
# 38515              110029            DE              Delhi             47.00
#
#        ... last contract line item last contract header start date  \
# ...

# %%
df.drop([441,7289,38515],inplace=True)

# %%
df
# Out:
#       company code  equipment number bill-to customer number  \
# 0      hello world          17279051              0001146594
# 3             2040          16498250              0001289243
# 4             2040          17072866              0001655736
# 5             2040          16556865                 ICG2040
# 6             2040          12679129                     NaN
# ...            ...               ...                     ...
# 54558         2040          16549601              0001141341
# 54559         2040          16616453              0001289273
# 54560         2040          16335107                     NaN
# 54561         2040          12573049                     NaN
# 54562         2040          14892414                     NaN
#
#       sold-to customer number ship-to customer number  ship-to city  \
# 0                  0001146594              0001146594    CHANDIGARH
# 3                  0001289243              0001655354         Jammu
# ...

# %%
df['ageing_average']=np.where(df['Ageing of the product (in years)']>df['Ageing of the product (in years)'].mean(),"above_average", "below_average")

# %%
conditions=[(df["Ageing of the product (in years)"]<=3),
        (df["Ageing of the product (in years)"]>3) & (df["Ageing of the product (in years)"]<=7),
        (df["Ageing of the product (in years)"]>7) & (df["Ageing of the product (in years)"]<=14),
        (df["Ageing of the product (in years)"]>14) & (df["Ageing of the product (in years)"]<=20),
        (df["Ageing of the product (in years)"]>20), df["Ageing of the product (in years)"].isnull()]
values=["new product purchased", "check for service", "service requirment", "need replacement", "need replacement immidieately", "Missing"]
df["Bucketing/Binning"]=np.select(conditions,values)

# %%
df["Bucketing/Binning"].value_counts().plot(kind='bar')
df["Bucketing/Binning"].value_counts()
# Out:
# service requirment               20291
# check for service                17164
# new product purchased            15652
# need replacement                  1274
# need replacement immidieately       57
# Name: Bucketing/Binning, dtype: int64

# %%
corr=df.corr()
plt.figure(figsize=(30,20))
plt.title('Pearson Correlation of Features', y=1, size=40)
sns.heatmap(corr,linewidths=-1,vmax=1.0,square=True, cmap='hot', linecolor='Black',annot=True)
plt.show()
# Out:
# /var/folders/sy/lfmt7xdx3zj5qzj0mw834nzw0000gn/T/ipykernel_40515/1175297422.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
student1 = [23,17,35,29,12]
plt.bar(langs,student1)
plt.show()

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
student1 = [40,17,35,29,12]
student2=[40,80,10,55,43]
plt.bar(langs, student1, color='r')
plt.bar(langs,student2, bottom=student1, color='b')
plt.show()

# %%
x=np.arange(4)
labels = ['C', 'C++', 'Java', 'Python']
plt.bar(x,[10,20,30,40],color="b",width=0.25)
plt.bar(x+.25,[40,25,50,50],color="r",width=0.25)
plt.xticks(x,labels, rotation='horizontal')
plt.show()

# %%
plt.hist(np.random.rand(100), bins=10)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
data = np.random.normal(100, 20, 200)
#fig = plt.figure(figsize =(10, 7))
plt.boxplot(data)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
z = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]



fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
ax1.hist(np.random.rand(100), bins=20)
ax2.plot(np.random.rand(100))
ax3.scatter(x, y)
ax4.pie(z, labels = mylabels)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
z = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]


fig,axis=plt.subplots(2,2)
axis[0,0].hist(np.random.rand(100),bins=10)
axis[0,1].plot(np.random.rand(100))
axis[1,0].scatter(x, y)
axis[1,1].pie(z,labels=mylabels)
plt.show()

# %%
fig,axis=plt.subplots(2,2,sharex=True,sharey=True, figsize=(6,8))###gridspec_kw={'width_ratios': [1, 2]}
plt.subplots_adjust(wspace=0,hspace=0)
axis[0,0].hist(np.random.rand(100),bins=10,color="r", label="histo")
axis[0,0].legend(loc="best")
axis[0,0].set_xlabel("xlabel")
axis[0,0].set_ylabel("ylabel")
axis[0,0].set_title("first plot")
axis[0,1].plot(np.random.rand(100),color="g",linestyle="--", marker="o")
plot_label={'title':'Second Plot',
           'xlabel':'X-Axis'}
axis[0,1].set(**plot_label)
axis[1,0].scatter(x, y,color="y")
axis[1,1].pie(z,labels=mylabels)
plt.show()

# %%
sns.heatmap(df.isnull(),cbar=True)
# Out:
# <Axes: >
