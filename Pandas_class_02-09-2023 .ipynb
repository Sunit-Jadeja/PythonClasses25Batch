# %%
import pandas as pd

# %%
df=pd.read_excel("/Users/sunitjadeja/Desktop/PandasData.xlsx")

# %%
#df=pd.read_excel("PandasData.xlsx")

# %%
df
# Out:
#       company code  equipment number bill-to customer number  \
# 0      hello world          17279051              0001146594
# 1             2040          17194740              0001665650
# 2             2040          17202899              0001509501
# 3             2040          16498250              0001289243
# 4             2040          17072866              0001655736
# ...            ...               ...                     ...
# 54558         2040          16549601              0001141341
# 54559         2040          16616453              0001289273
# 54560         2040          16335107                     NaN
# 54561         2040          12573049                     NaN
# 54562         2040          14892414                     NaN
#
#       sold-to customer number ship-to customer number  ship-to city  \
# 0                  0001146594              0001146594    CHANDIGARH
# 1                  0001665650              0001665650     Hyderabad
# ...

# %%
print(df.dtypes)###without change
# Out:
# company code                                  int64
# equipment number                              int64
# bill-to customer number                      object
# sold-to customer number                      object
# ship-to customer number                      object
#                                           ...
# future contract line item                   float64
# future contract header start date    datetime64[ns]
# future contract header end date      datetime64[ns]
# load_date                            datetime64[ns]
# corrected division                           object
# Length: 66, dtype: object

# %%
df.dtypes
# Out:
# company code                                 object
# equipment number                              int64
# bill-to customer number                      object
# sold-to customer number                      object
# ship-to customer number                      object
#                                           ...
# future contract line item                   float64
# future contract header start date    datetime64[ns]
# future contract header end date      datetime64[ns]
# load_date                            datetime64[ns]
# corrected division                           object
# Length: 66, dtype: object

# %%
print (df.isnull().sum())
# Out:
# company code                             0
# equipment number                         0
# bill-to customer number              21831
# sold-to customer number                962
# ship-to customer number                678
#                                      ...
# future contract line item            53522
# future contract header start date    53522
# future contract header end date      53522
# load_date                                0
# corrected division                       0
# Length: 66, dtype: int64

# %%
print (df.columns)
# Out:
# Index(['company code', 'equipment number', 'bill-to customer number',
#        'sold-to customer number', 'ship-to customer number', 'ship-to city',
#        'ship-to postal code', 'ship-to state', 'ship-to state name',
#        'industry segment', 'industry segment description',
#        'customer classification', 'customer class description',
#        'industry code', 'customer account type direct_asp', 'asp name',
#        'customer group code', 'focus account',
#        'last end user contact telephone ism2',
#        'last end user contact mobile ism2', 'last end user contact email ism',
#        'most used contact email ism2', 'most used email count ism',
#        'equipment fse number', 'equipment model', 'equipment model name',
#        'equipment material', 'equipment material description',
#        'equipment serial number', 'sort field', 'superior equipment',
#        'superior equipment description', 'product planner group',
# ...

# %%
df.tail(5)
# Out:
#       company code  equipment number bill-to customer number  \
# 54558         2040          16549601              0001141341
# 54559         2040          16616453              0001289273
# 54560         2040          16335107                     NaN
# 54561         2040          12573049                     NaN
# 54562         2040          14892414                     NaN
#
#       sold-to customer number ship-to customer number  ship-to city  \
# 54558              0001141341              0001141341     NEW DELHI
# 54559              0001289273              0001289273       GURGAON
# 54560              0001624691              0001624691        Mumbai
# 54561              0001147571              0001147571     New Delhi
# 54562              0001503727              0001503727  Mahendragarh
#
#       ship-to postal code ship-to state ship-to state name  industry segment  \
# 54558              110067            DE              Delhi              90.0
# ...

# %%
df1=df.copy()

# %%
df1["logic date"]="hello world"

# %%
df1.drop(columns=["logic date"], inplace=True)

# %%
df.set_index("equipment number", inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#        equipment number company code bill-to customer number  \
# 0              17279051  hello world              0001146594
# 1              17194740         2040              0001665650
# 2              17202899         2040              0001509501
# 3              16498250         2040              0001289243
# 4              17072866         2040              0001655736
# ...                 ...          ...                     ...
# 54558          16549601         2040              0001141341
# 54559          16616453         2040              0001289273
# 54560          16335107         2040                     NaN
# 54561          12573049         2040                     NaN
# 54562          14892414         2040                     NaN
#
#       sold-to customer number ship-to customer number  ship-to city  \
# 0                  0001146594              0001146594    CHANDIGARH
# 1                  0001665650              0001665650     Hyderabad
# ...

# %%
column_3=df[["equipment number", "equipment model name", "corrected division"]]

# %%
#column_3.set_index("equipment number",inplace =True)
column_3.iloc[54000]
# Out:
# equipment model name    NANO2000
# corrected division           MOL
# Name: 15726279, dtype: object

# %%
column_3.loc[16498250]
# Out:
# equipment model name    Precision Bath
# corrected division                 LSI
# Name: 16498250, dtype: object

# %%
df.set_index("equipment number", inplace=True)

# %%
df
# Out:
#                  company code bill-to customer number sold-to customer number  \
# equipment number
# 17279051          hello world              0001146594              0001146594
# 17194740                 2040              0001665650              0001665650
# 17202899                 2040              0001509501              0001509501
# 16498250                 2040              0001289243              0001289243
# 17072866                 2040              0001655736              0001655736
# ...                       ...                     ...                     ...
# 16549601                 2040              0001141341              0001141341
# 16616453                 2040              0001289273              0001289273
# 16335107                 2040                     NaN              0001624691
# 12573049                 2040                     NaN              0001147571
# 14892414                 2040                     NaN              0001503727
#
# ...

# %%
df.loc[17202899]
# Out:
# company code                                               2040
# bill-to customer number                              0001509501
# sold-to customer number                              0001509501
# ship-to customer number                              0001509501
# ship-to city                                           Vadodara
#                                                 ...
# future contract line item                                  10.0
# future contract header start date           2022-07-19 00:00:00
# future contract header end date             2026-07-18 00:00:00
# load_date                            2022-06-16 01:38:48.728000
# corrected division                                          CMD
# Name: 17202899, Length: 65, dtype: object

# %%
df.iloc[2]
# Out:
# company code                                               2040
# bill-to customer number                              0001509501
# sold-to customer number                              0001509501
# ship-to customer number                              0001509501
# ship-to city                                           Vadodara
#                                                 ...
# future contract line item                                  10.0
# future contract header start date           2022-07-19 00:00:00
# future contract header end date             2026-07-18 00:00:00
# load_date                            2022-06-16 01:38:48.728000
# corrected division                                          CMD
# Name: 17202899, Length: 65, dtype: object

# %%
df.loc[17202899,["company code", "corrected division"]]
# Out:
# company code          2040
# corrected division     CMD
# Name: 17202899, dtype: object

# %%
df.iloc[2,[0,64]]
# Out:
# company code          2040
# corrected division     CMD
# Name: 17202899, dtype: object

# %%
df.loc[:17202899,:]
# Out:
#                  company code bill-to customer number sold-to customer number  \
# equipment number
# 17279051          hello world              0001146594              0001146594
# 17194740                 2040              0001665650              0001665650
# 17202899                 2040              0001509501              0001509501
#
#                  ship-to customer number ship-to city ship-to postal code  \
# equipment number
# 17279051                      0001146594   CHANDIGARH              160012
# 17194740                      0001665650    Hyderabad              501401
# 17202899                      0001509501     Vadodara              391450
#
#                  ship-to state ship-to state name  industry segment  \
# equipment number
# 17279051                    CD         Chandigarh              47.0
# 17194740                    TG          Telangana             109.0
# 17202899                    GU            Gujarat              11.0
#
# ...

# %%
df.loc[:17202899,"sold-to customer number":"industry segment"]
# Out:
#                  sold-to customer number ship-to customer number ship-to city  \
# equipment number
# 17279051                      0001146594              0001146594   CHANDIGARH
# 17194740                      0001665650              0001665650    Hyderabad
# 17202899                      0001509501              0001509501     Vadodara
#
#                  ship-to postal code ship-to state ship-to state name  \
# equipment number
# 17279051                      160012            CD         Chandigarh
# 17194740                      501401            TG          Telangana
# 17202899                      391450            GU            Gujarat
#
#                   industry segment
# equipment number
# 17279051                      47.0
# 17194740                     109.0
# 17202899                      11.0

# %%
df
# Out:
#                  company code bill-to customer number sold-to customer number  \
# equipment number
# 17279051          hello world              0001146594              0001146594
# 17194740                 2040              0001665650              0001665650
# 17202899                 2040              0001509501              0001509501
# 16498250                 2040              0001289243              0001289243
# 17072866                 2040              0001655736              0001655736
# ...                       ...                     ...                     ...
# 16549601                 2040              0001141341              0001141341
# 16616453                 2040              0001289273              0001289273
# 16335107                 2040                     NaN              0001624691
# 12573049                 2040                     NaN              0001147571
# 14892414                 2040                     NaN              0001503727
#
# ...

# %%
#df.iloc[0:3,:]
df.iloc[0:3,:5]
# Out:
#                  company code bill-to customer number sold-to customer number  \
# equipment number
# 17279051          hello world              0001146594              0001146594
# 17194740                 2040              0001665650              0001665650
# 17202899                 2040              0001509501              0001509501
#
#                  ship-to customer number ship-to city
# equipment number
# 17279051                      0001146594   CHANDIGARH
# 17194740                      0001665650    Hyderabad
# 17202899                      0001509501     Vadodara

# %%
df.iloc[:100,:10]
# Out:
#                  company code bill-to customer number sold-to customer number  \
# equipment number
# 17279051          hello world              0001146594              0001146594
# 17194740                 2040              0001665650              0001665650
# 17202899                 2040              0001509501              0001509501
# 16498250                 2040              0001289243              0001289243
# 17072866                 2040              0001655736              0001655736
# ...                       ...                     ...                     ...
# 12679145                 2040                     NaN              0001129658
# 16556986                 2040              0001598997              0001598997
# 14241236                 2040              0001159371              0001159371
# 15140710                 2040                     NaN              0001332016
# 16814429                 2040              0001289243              0001289243
#
# ...

# %%
d={"col1":[100,200,300],
"col3":[10,20,30],
 "col2":[1,3,3]}
df=pd.DataFrame(d)

# %%
df
# Out:
#    col1  col3  col2
# 0   100    10     1
# 1   200    20     3
# 2   300    30     3

# %%
df.sort_index(axis=1)
# Out:
#    col1  col2  col3
# 0   100     1    10
# 1   200     2    20
# 2   300     3    30

# %%
df.sort_index(axis=1)
# Out:
#       aag aag description active contract header end date  \
# 0      20       Equipment                             NaT
# 1      20       Equipment                             NaT
# 2      20       Equipment                             NaT
# 3      20       Equipment                             NaT
# 4      20       Equipment                             NaT
# ...    ..             ...                             ...
# 54558  20       Equipment                             NaT
# 54559  20       Equipment                             NaT
# 54560  20       Equipment                             NaT
# 54561  20       Equipment                             NaT
# 54562  20       Equipment                             NaT
#
#        active contract header value  active contract line value asp name  \
# 0                               NaN                         NaN      TBD
# 1                               NaN                         NaN      TBD
# ...

# %%
df
# Out:
#       company code  equipment number bill-to customer number  \
# 0      hello world          17279051              0001146594
# 1             2040          17194740              0001665650
# 2             2040          17202899              0001509501
# 3             2040          16498250              0001289243
# 4             2040          17072866              0001655736
# ...            ...               ...                     ...
# 54558         2040          16549601              0001141341
# 54559         2040          16616453              0001289273
# 54560         2040          16335107                     NaN
# 54561         2040          12573049                     NaN
# 54562         2040          14892414                     NaN
#
#       sold-to customer number ship-to customer number  ship-to city  \
# 0                  0001146594              0001146594    CHANDIGARH
# 1                  0001665650              0001665650     Hyderabad
# ...

# %%
df.sort_values(by=["col2", "col3"],ascending=False)
# Out:
#    col1  col3  col2
# 2   300    30     3
# 1   200    20     3
# 0   100    10     1

# %%
df.rank(axis=1)
# Out:
#    col1  col3  col2
# 0   3.0   2.0   1.0
# 1   3.0   2.0   1.0
# 2   3.0   2.0   1.0

# %%
df
# Out:
#    col1  col3  col2
# 0   100    10     1
# 1   200    20     3
# 2   300    30     3
