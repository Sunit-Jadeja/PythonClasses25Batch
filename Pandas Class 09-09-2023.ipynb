# %%
import pandas as pd

# %%
df=pd.read_excel("/Users/sunitjadeja/Desktop/PandasData.xlsx")

# %% [markdown]
# # Shape of DataFrame

# %%
####Shape of DataFrame
#df.shape
random.randint(0,39)
# Out:
# 28

# %%
df["equipment model name"].notnull().sum()
# Out:
# 49376

# %%
df.dtypes
# Out:
# company code                                 object
# equipment number                              int64
# bill-to customer number                      object
# sold-to customer number                      object
# ship-to customer number                      object
#                                           ...
# future contract line item                   float64
# future contract header start date    datetime64[ns]
# future contract header end date      datetime64[ns]
# load_date                            datetime64[ns]
# corrected division                           object
# Length: 66, dtype: object

# %%
df["name10"]=df["company code"]*10

# %%
df.reset_index(inplace=True)

# %%
import numpy as np
df["USD dollar"]=np.random.randint(1000,100000, size=len(df))

# %%
len(df)
# Out:
# 54563

# %%
df
# Out:
#        equipment number  company code bill-to customer number  \
# 0              17279051          2040              0001146594
# 1              17194740          2040              0001665650
# 2              17202899          2040              0001509501
# 3              16498250          2040              0001289243
# 4              17072866          2040              0001655736
# ...                 ...           ...                     ...
# 54558          16549601          2040              0001141341
# 54559          16616453          2040              0001289273
# 54560          16335107          2040                     NaN
# 54561          12573049          2040                     NaN
# 54562          14892414          2040                     NaN
#
#       sold-to customer number ship-to customer number  ship-to city  \
# 0                  0001146594              0001146594    CHANDIGARH
# 1                  0001665650              0001665650     Hyderabad
# ...

# %%
df.drop(columns=["name", "name10"],inplace=True)

# %%
df["USD dollar"].nunique()
# Out:
# 41891

# %%
for col in df.columns:
    print(col,df[col].value_counts())
# Out:
# equipment number 17279051    1
# 13664682    1
# 15796903    1
# 13360591    1
# 16137803    1
#            ..
# 15064138    1
# 12306388    1
# 15707357    1
# 12872592    1
# 14892414    1
# Name: equipment number, Length: 54563, dtype: int64
# company code 2040    54563
# Name: company code, dtype: int64
# bill-to customer number 0001141920    482
# 0001218496    247
# 0001289243    244
# 0001221399    186
# 0001140271    176
#              ...
# 0001139945      1
# 0001140834      1
# 0001442633      1
# 0001592907      1
# 0001139911      1
# Name: bill-to customer number, Length: 7555, dtype: int64
# sold-to customer number 0001141920    487
# 0001218496    312
# 0001289243    248
# 0001079499    243
# 0001221399    234
#              ...
# 0001288365      1
# 0001527170      1
# 0001647033      1
# 0001154839      1
# 0001624691      1
# Name: sold-to customer number, Length: 9814, dtype: int64
# ship-to customer number 0001141920    485
# 0001079499    247
# ...

# %%
df1=df.copy()

# %%
df["company code"]=df["company code"].replace(to_replace="hello world", value=2040).astype(int)

# %%
#df[df["ship-to city"].isnull()]
#13328335

# %%
#54563-1150
df["ship-to city"]=df["ship-to city"].str.lower()
# Out:
#      company code  equipment number bill-to customer number  \
# 516          2040          13328335                     NaN
#
#     sold-to customer number ship-to customer number ship-to city  \
# 516                     NaN                     NaN          NaN
#
#     ship-to postal code ship-to state ship-to state name  industry segment  \
# 516                 NaN           NaN                NaN               NaN
#
#      ... last contract number last contract line item  \
# 516  ...           40226508.0                    10.0
#
#     last contract header start date  last contract header end date  \
# 516                      2017-05-18                     2018-05-17
#
#     future contract line item future contract header start date  \
# 516                       NaN                               NaT
#
#     future contract header end date               load_date  \
# 516                             NaT 2022-06-16 01:38:48.728
#
#     corrected division         name
# ...

# %%
df.dropna(subset=["ship-to city"])
# Out:
#        company code  equipment number bill-to customer number  \
# 0              2040          17279051              0001146594
# 1              2040          17194740              0001665650
# 2              2040          17202899              0001509501
# 3              2040          16498250              0001289243
# 4              2040          17072866              0001655736
# ...             ...               ...                     ...
# 54558          2040          16549601              0001141341
# 54559          2040          16616453              0001289273
# 54560          2040          16335107                     NaN
# 54561          2040          12573049                     NaN
# 54562          2040          14892414                     NaN
#
#       sold-to customer number ship-to customer number  ship-to city  \
# 0                  0001146594              0001146594    CHANDIGARH
# 1                  0001665650              0001665650     Hyderabad
# ...

# %%
null_experiment=df.dropna(how="all")

# %%
df.isnull().sum()
# Out:
# equipment number                         0
# company code                             0
# bill-to customer number              21189
# sold-to customer number                316
# ship-to customer number                  0
#                                      ...
# future contract header start date    52847
# future contract header end date      52847
# load_date                                0
# corrected division                       0
# USD dollar                               0
# Length: 67, dtype: int64

# %%
df_mean_exp=df.fillna(df.mean())
# Out:
# /var/folders/sy/lfmt7xdx3zj5qzj0mw834nzw0000gn/T/ipykernel_3025/3904673407.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df_mean_exp=df.fillna(df.mean())
# /var/folders/sy/lfmt7xdx3zj5qzj0mw834nzw0000gn/T/ipykernel_3025/3904673407.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mean_exp=df.fillna(df.mean())

# %%
pd.set_option("display.min_rows",100)
df_mean_exp.isnull().sum()
# Out:
# equipment number                            0
# company code                                0
# bill-to customer number                 21189
# sold-to customer number                   316
# ship-to customer number                     0
# ship-to city                                0
# ship-to postal code                       209
# ship-to state                             473
# ship-to state name                        472
# industry segment                            0
# industry segment description              739
# customer classification                 42487
# customer class description              42487
# industry code                               0
# customer account type direct_asp            0
# asp name                                    0
# customer group code                      1695
# focus account                               0
# last end user contact telephone ism2    27683
# last end user contact mobile ism2       27714
# ...

# %%
d

# %%
df.isnull().sum()
# Out:
# equipment number                            0
# company code                                0
# bill-to customer number                 21189
# sold-to customer number                   316
# ship-to customer number                     0
# ship-to city                                0
# ship-to postal code                       209
# ship-to state                             473
# ship-to state name                        472
# industry segment                          739
# industry segment description              739
# customer classification                 42487
# customer class description              42487
# industry code                            5755
# customer account type direct_asp            0
# asp name                                    0
# customer group code                      1695
# focus account                               0
# last end user contact telephone ism2    27683
# last end user contact mobile ism2       27714
# ...

# %%
mean_industry=df.fillna(df["industry code"].mean())
df[df["equipment number"]==17286767]
# Out:
#      equipment number  company code bill-to customer number  \
# 428          17286767          2040              0001575073
#
#     sold-to customer number ship-to customer number ship-to city  \
# 428              0001575073              0001141661    bangalore
#
#     ship-to postal code ship-to state ship-to state name  industry segment  \
# 428              560064            KA          Karnataka               NaN
#
#     industry segment description customer classification  \
# 428                          NaN                     NaN
#
#     customer class description  industry code  \
# 428                        NaN       423490.0
#
#     customer account type direct_asp asp name customer group code  \
# 428                              TBD      TBD                 NaN
#
#     focus account last end user contact telephone ism2  \
# 428            No                              9999999
#
#     last end user contact mobile ism2 last end user contact email ism  \
# ...

# %%
df["industry code"].mean()
# Out:
# 466907.5107417411

# %%
df[df['industry segment'].isnull()]
# Out:
#        equipment number  company code bill-to customer number  \
# 428            17286767          2040              0001575073
# 477            17279880          2040              0001668279
# 809            15677942          2040              0001067042
# 885            12013811          2040              0001143194
# 901            17342397          2040              0001575073
# 1070           17641176          2040              0001606512
# 1079           11622081          2040                     NaN
# 1172           13323354          2040                     NaN
# 1292           17641174          2040              0001606512
# 1354           14753156          2040              0001545010
# 1382           17443018          2040              0001617418
# 1404           11622052          2040                     NaN
# 1436           14928678          2040                     NaN
# 1522           11622162          2040                     NaN
# ...

# %%
df.fillna(df.rolling(67,min_periods=3).mean())
# Out:
# /var/folders/sy/lfmt7xdx3zj5qzj0mw834nzw0000gn/T/ipykernel_3025/1827926547.py:1: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['aag', 'aag description', 'active contract header end date', 'asp name',
#        'bill-to customer number', 'corrected division',
#        'customer account type direct_asp', 'customer class description',
#        'customer classification', 'customer group code',
#        'equipment created on', 'equipment installed on', 'equipment material',
#        'equipment material description', 'equipment model',
#        'equipment model name', 'equipment serial number',
#        'equipment shipped date', 'equipment status', 'equipment system status',
#        'equipment usage', 'equipment user status',
#        'extended warranty end date', 'extended warranty start date',
# ...

# %%
df_new2=df.fillna("HELLO WORLD")

# %%
df.drop_duplicates(subset=["ship-to city"],keep="last")
# Out:
#        equipment number  company code bill-to customer number  \
# 369            16556985          2040              0001598997
# 447            13766445          2040                     NaN
# 477            17279880          2040              0001668279
# 616            15602901          2040                     NaN
# 646            10475571          2040              0001260306
# 761            11698612          2040              0001153455
# 775            12449285          2040                     NaN
# 1138           10455817          2040              0001320565
# 1164           12286063          2040                     NaN
# 1193           17130412          2040              0001471125
# 1215           11341854          2040              0001104340
# 1353           14689527          2040                     NaN
# 1399           14059553          2040                     NaN
# 1473           13852919          2040              0001138384
# ...

# %%
func=lambda x:x.max()

# %%
def fun(x):
    x=x.min(), x.max(), x.sum()
    return x

# %%
df1=df[["industry segment","industry code",
        "equipment fse number", "active contract line value"]]
#[col for col in df.columns if "equip" in col.lower()]

# %%
df1.apply(func, axis=1)
# Out:
# 0         541410.00
# 1         541715.00
# 2             11.00
# 3         325412.00
# 4         541715.00
# 5         423490.00
# 6         561311.00
# 7         325414.00
# 8         999990.00
# 9         325412.00
# 10        325199.00
# 11        325412.00
# 12        611699.00
# 13        325412.00
# 14        423450.00
# 15        541715.00
# 16        561311.00
# 17        491110.00
# 18        325412.00
# 19        561311.00
# 20        541690.00
# 21        874999.98
# 22        541380.00
# 23        611699.00
# 24        312230.00
# 25        999990.00
# 26        500000.04
# 27        325412.00
# 28        541380.00
# 29        325412.00
#             ...
# 54533     333249.00
# 54534      91905.00
# 54535     325414.00
# 54536     213112.00
# 54537    1072572.00
# 54538     325412.00
# 54539     541715.00
# 54540     424990.00
# 54541     541715.00
# 54542     611210.00
# 54543     611310.00
# 54544     921190.00
# 54545      91426.00
# 54546     622110.00
# ...

# %%
df1#["industry segment"].max()
# Out:
#        industry segment  industry code  equipment fse number  \
# 0                  47.0       541410.0                   NaN
# 1                 109.0       541715.0                   NaN
# 2                  11.0            NaN                   NaN
# 3                  27.0       325412.0               91935.0
# 4                  19.0       541715.0               91946.0
# 5                  27.0       423490.0                   NaN
# 6                 111.0       561311.0               91915.0
# 7                  63.0       325414.0                   NaN
# 8                 108.0       999990.0                   NaN
# 9                  27.0       325412.0               91908.0
# 10                  6.0       325199.0                   NaN
# 11                 90.0       325412.0                   NaN
# 12                 90.0       611699.0                   NaN
# 13                 90.0       325412.0                   NaN
# ...

# %%
f1=lambda x:x*10
df1.applymap(f1)
# Out:
#        industry segment  industry code  equipment fse number  \
# 0                 470.0      5414100.0                   NaN
# 1                1090.0      5417150.0                   NaN
# 2                 110.0            NaN                   NaN
# 3                 270.0      3254120.0              919350.0
# 4                 190.0      5417150.0              919460.0
# 5                 270.0      4234900.0                   NaN
# 6                1110.0      5613110.0              919150.0
# 7                 630.0      3254140.0                   NaN
# 8                1080.0      9999900.0                   NaN
# 9                 270.0      3254120.0              919080.0
# 10                 60.0      3251990.0                   NaN
# 11                900.0      3254120.0                   NaN
# 12                900.0      6116990.0                   NaN
# 13                900.0      3254120.0                   NaN
# ...

# %%
df.applymap(lambda s:s.lower() if type (s)==str else s)
# Out:
#        equipment number  company code bill-to customer number  \
# 0              17279051          2040              0001146594
# 1              17194740          2040              0001665650
# 2              17202899          2040              0001509501
# 3              16498250          2040              0001289243
# 4              17072866          2040              0001655736
# 5              16556865          2040                 icg2040
# 6              12679129          2040                     NaN
# 7              16438610          2040              0001140935
# 8              17271465          2040              0001657856
# 9              16644012          2040              0001289243
# 10             16285984          2040              0001629806
# 11             17266956          2040              0001288904
# 12             17070621          2040              0001137862
# 13             17266952          2040              0001288904
# ...

# %%
df["ship-to city"].value_counts()
# Out:
# bangalore                        3892
# hyderabad                        3150
# pune                             2738
# mumbai                           2225
# ahmedabad                        1699
# new delhi                        1685
# chennai                          1409
# navi mumbai                      1235
# kolkata                          1104
# vadodara                          772
# delhi                             755
# gurgaon                           740
# lucknow                           720
# valsad                            525
# guwahati                          465
# aurangabad                        461
# thane                             439
# chandigarh                        423
# faridabad                         371
# thiruvananthapuram                367
# jaipur                            358
# visakhapatnam                     339
# jammu                             322
# bhubaneswar                       320
# coimbatore                        294
# ...

# %%
[col for col in df.columns if "ship" in col.lower()]
# Out:
# ['ship-to customer number',
#  'ship-to city',
#  'ship-to postal code',
#  'ship-to state',
#  'ship-to state name',
#  'equipment shipped date']

# %%
(col for col in df.columns if "installed" in col.lower())
# Out:
# <generator object <genexpr> at 0x14a6d5380>
